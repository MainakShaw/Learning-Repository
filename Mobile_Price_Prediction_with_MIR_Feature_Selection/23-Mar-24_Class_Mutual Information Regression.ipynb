# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("mobile_prices_2023.csv")

# %%
data.head()
# Out:
#                       Phone Name  Rating ?/5 Number of Ratings       RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2            33,561  2 GB RAM
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128  4 GB RAM
# 2   POCO C51 (Royal Blue, 64 GB)         4.3            15,175  4 GB RAM
# 3    POCO C55 (Cool Blue, 64 GB)         4.2            22,621  4 GB RAM
# 4  POCO C51 (Power Black, 64 GB)         4.3            15,175  4 GB RAM
#
#   ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM        8MP Dual Camera  5MP Front Camera  5000 mAh
# 1   64 GB ROM             50MP + 2MP  8MP Front Camera  5000 mAh
# 2   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 3   64 GB ROM  50MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 4   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR  \
# ...

# %%
data.isnull().sum()
# Out:
# Phone Name             0
# Rating ?/5             0
# Number of Ratings      0
# RAM                    0
# ROM/Storage          174
# Back/Rare Camera       9
# Front Camera         401
# Battery               10
# Processor             55
# Price in INR           0
# Date of Scraping       0
# dtype: int64

# %%
data.shape
# Out:
# (1836, 11)

# %%
data = data.dropna()

# %%
data
# Out:
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2            33,561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3            15,175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2            22,621
# 4                POCO C51 (Power Black, 64 GB)         4.3            15,175
# ...                                        ...         ...               ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25,582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25,582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25,582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7,117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15,701
#
# ...

# %%
data.drop("Date of Scraping", axis = 1, inplace = True)

# %%
data
# Out:
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2            33,561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3            15,175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2            22,621
# 4                POCO C51 (Power Black, 64 GB)         4.3            15,175
# ...                                        ...         ...               ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25,582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25,582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25,582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7,117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15,701
#
# ...

# %%
data["Price in INR"].str.replace("₹","")
# Out:
# 0        5,649
# 1       11,999
# 2        6,999
# 3        7,749
# 4        6,999
#          ...
# 1831    14,999
# 1832    14,999
# 1833    14,999
# 1834    18,999
# 1835    10,999
# Name: Price in INR, Length: 1291, dtype: object

# %%
data["Price in INR"]
# Out:
# 0        ₹5,649
# 1       ₹11,999
# 2        ₹6,999
# 3        ₹7,749
# 4        ₹6,999
#          ...
# 1831    ₹14,999
# 1832    ₹14,999
# 1833    ₹14,999
# 1834    ₹18,999
# 1835    ₹10,999
# Name: Price in INR, Length: 1291, dtype: object

# %%
data["Price in INR"] = data["Price in INR"].str.replace("₹","")

# %%
data["Price in INR"]
# Out:
# 0        5,649
# 1       11,999
# 2        6,999
# 3        7,749
# 4        6,999
#          ...
# 1831    14,999
# 1832    14,999
# 1833    14,999
# 1834    18,999
# 1835    10,999
# Name: Price in INR, Length: 1291, dtype: object

# %%
data["Price in INR"] = data["Price in INR"].str.replace(",","")

# %%
data["Price in INR"]
# Out:
# 0        5649
# 1       11999
# 2        6999
# 3        7749
# 4        6999
#         ...
# 1831    14999
# 1832    14999
# 1833    14999
# 1834    18999
# 1835    10999
# Name: Price in INR, Length: 1291, dtype: object

# %%
data["Price in INR"] = data["Price in INR"].astype("int")

# %%
data["Price in INR"]
# Out:
# 0        5649
# 1       11999
# 2        6999
# 3        7749
# 4        6999
#         ...
# 1831    14999
# 1832    14999
# 1833    14999
# 1834    18999
# 1835    10999
# Name: Price in INR, Length: 1291, dtype: int32

# %%
data
# Out:
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2            33,561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3            15,175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2            22,621
# 4                POCO C51 (Power Black, 64 GB)         4.3            15,175
# ...                                        ...         ...               ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25,582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25,582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25,582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7,117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15,701
#
# ...

# %%
data['Processor']
# Out:
# 0       Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...
# 1                        Mediatek Dimensity 700 Processor
# 2                                     Helio G36 Processor
# 3                            Mediatek Helio G85 Processor
# 4                                     Helio G36 Processor
#                               ...
# 1831                         MediaTek Helio G70 Processor
# 1832                         MediaTek Helio G70 Processor
# 1833                         MediaTek Helio G70 Processor
# 1834                        MediaTek Helio G90T Processor
# 1835                        Helio P22 (MTK6762) Processor
# Name: Processor, Length: 1291, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data['Processor'] = le.fit_transform(data['Processor'])

# %%
data
# Out:
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2            33,561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3            15,175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2            22,621
# 4                POCO C51 (Power Black, 64 GB)         4.3            15,175
# ...                                        ...         ...               ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25,582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25,582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25,582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7,117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15,701
#
# ...

# %%
data["Battery"]
# Out:
# 0       5000 mAh
# 1       5000 mAh
# 2       5000 mAh
# 3       5000 mAh
# 4       5000 mAh
#           ...
# 1831    5000 mAh
# 1832    5000 mAh
# 1833    5000 mAh
# 1834    4500 mAh
# 1835    4000 mAh
# Name: Battery, Length: 1291, dtype: object

# %%
data["Battery"] = data["Battery"].str.replace(" mAh", "")

# %%
data["Battery"] = data["Battery"].astype("int")

# %%
data
# Out:
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2            33,561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3            15,175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2            22,621
# 4                POCO C51 (Power Black, 64 GB)         4.3            15,175
# ...                                        ...         ...               ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25,582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25,582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25,582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7,117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15,701
#
# ...

# %%
data["Front Camera"] = le.fit_transform(data["Front Camera"])

# %%
data
# Out:
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2            33,561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3            15,175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2            22,621
# 4                POCO C51 (Power Black, 64 GB)         4.3            15,175
# ...                                        ...         ...               ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25,582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25,582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25,582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7,117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15,701
#
# ...

# %%
data.drop("Phone Name", axis = 1, inplace = True)

# %%
data
# Out:
#       Rating ?/5 Number of Ratings       RAM ROM/Storage  \
# 0            4.2            33,561  2 GB RAM   32 GB ROM
# 1            4.2            77,128  4 GB RAM   64 GB ROM
# 2            4.3            15,175  4 GB RAM   64 GB ROM
# 3            4.2            22,621  4 GB RAM   64 GB ROM
# 4            4.3            15,175  4 GB RAM   64 GB ROM
# ...          ...               ...       ...         ...
# 1831         4.3            25,582  4 GB RAM   64 GB ROM
# 1832         4.3            25,582  4 GB RAM   64 GB ROM
# 1833         4.3            25,582  4 GB RAM   64 GB ROM
# 1834         4.2             7,117  8 GB RAM  128 GB ROM
# 1835         4.3            15,701  4 GB RAM   64 GB ROM
#
#                          Back/Rare Camera  Front Camera  Battery  Processor  \
# 0                         8MP Dual Camera            26     5000        116
# 1                              50MP + 2MP            31     5000        102
# ...

# %%
data['Number of Ratings'] = data['Number of Ratings'].str.replace(',','').astype("int")

# %%
data
# Out:
#       Rating ?/5  Number of Ratings       RAM ROM/Storage  \
# 0            4.2              33561  2 GB RAM   32 GB ROM
# 1            4.2              77128  4 GB RAM   64 GB ROM
# 2            4.3              15175  4 GB RAM   64 GB ROM
# 3            4.2              22621  4 GB RAM   64 GB ROM
# 4            4.3              15175  4 GB RAM   64 GB ROM
# ...          ...                ...       ...         ...
# 1831         4.3              25582  4 GB RAM   64 GB ROM
# 1832         4.3              25582  4 GB RAM   64 GB ROM
# 1833         4.3              25582  4 GB RAM   64 GB ROM
# 1834         4.2               7117  8 GB RAM  128 GB ROM
# 1835         4.3              15701  4 GB RAM   64 GB ROM
#
#                          Back/Rare Camera  Front Camera  Battery  Processor  \
# 0                         8MP Dual Camera            26     5000        116
# 1                              50MP + 2MP            31     5000        102
# ...

# %%
data.dtypes
# Out:
# Rating ?/5           float64
# Number of Ratings      int32
# RAM                   object
# ROM/Storage           object
# Back/Rare Camera      object
# Front Camera           int32
# Battery                int32
# Processor              int32
# Price in INR           int32
# dtype: object

# %%
for column in data.columns:
    if data.dtypes[column] == "object":
        data[column] = le.fit_transform(data[column])

# %%
data
# Out:
#       Rating ?/5  Number of Ratings  RAM  ROM/Storage  Back/Rare Camera  \
# 0            4.2              33561    4            4               144
# 1            4.2              77128    6            7                99
# 2            4.3              15175    6            7               145
# 3            4.2              22621    6            7               118
# 4            4.3              15175    6            7               145
# ...          ...                ...  ...          ...               ...
# 1831         4.3              25582    6            7                69
# 1832         4.3              25582    6            7                69
# 1833         4.3              25582    6            7                69
# 1834         4.2               7117    9            1                77
# 1835         4.3              15701    6            7                50
#
#       Front Camera  Battery  Processor  Price in INR
# ...

# %%
data.columns
# Out:
# Index(['Rating ?/5', 'Number of Ratings', 'RAM', 'ROM/Storage',
#        'Back/Rare Camera', 'Front Camera', 'Battery', 'Processor',
#        'Price in INR'],
#       dtype='object')

# %%
X = data[['Rating ?/5', 'Number of Ratings', 'RAM', 'ROM/Storage',
       'Back/Rare Camera', 'Front Camera', 'Battery', 'Processor',]]

# %%
y = data['Price in INR']

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
MIR = mutual_info_regression(X,y)

# %%
MIR
# Out:
# array([0.28577477, 0.99858051, 0.72373988, 0.54965336, 1.08578962,
#        0.71376175, 0.52711495, 1.10430696])

# %%
Mir_ser = pd.Series(MIR)

# %%
Mir_ser
# Out:
# 0    0.285775
# 1    0.998581
# 2    0.723740
# 3    0.549653
# 4    1.085790
# 5    0.713762
# 6    0.527115
# 7    1.104307
# dtype: float64

# %%
Mir_ser.index = X.columns

# %%
Mir_ser
# Out:
# Rating ?/5           0.285775
# Number of Ratings    0.998581
# RAM                  0.723740
# ROM/Storage          0.549653
# Back/Rare Camera     1.085790
# Front Camera         0.713762
# Battery              0.527115
# Processor            1.104307
# dtype: float64

# %%
import seaborn as sns

# %%
sns.barplot(x = Mir_ser.index, y = Mir_ser.values)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = Mir_ser.index, y = Mir_ser.values)
plt.xticks(rotation = 75)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Rating ?/5'),
#   Text(1, 0, 'Number of Ratings'),
#   Text(2, 0, 'RAM'),
#   Text(3, 0, 'ROM/Storage'),
#   Text(4, 0, 'Back/Rare Camera'),
#   Text(5, 0, 'Front Camera'),
#   Text(6, 0, 'Battery'),
#   Text(7, 0, 'Processor')])
